# %% [markdown]
# # Sample Size Determination for Two Sample T Test

# %% [markdown]
# The sample size needed for a Two Sample T Test depends on the data variation, the
# desired level of detection, and the probability of detection when there really is a
# difference (typically 80%).

# %%
from stats_tests import sample_size_2ttest
import numpy as np

# %%
result = sample_size_2ttest(mean1=0, mean2=0.01, std1=.00943, std2=.00943)
# Out:
# Required sample size per group: 15

# %% [markdown]
# - Note here 15 samples per group will give an 80% probability of detecting at least 1% difference in mean defect rates.
# -  In our case it’s a bit irrelevant as we have already showed a difference in prior analysis. But what if had not shown a difference? This could give us a clue that we need to get more samples, etc.
